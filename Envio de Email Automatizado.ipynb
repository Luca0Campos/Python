# %%
#!pip install pyautogui

# %%
import pyautogui
import pyperclip
import time

# %%
time.sleep (5)
pyautogui.position()
# Out:
# Point(x=445, y=246)

# %%
pyautogui.PAUSE = 2

# Entrar no Sistema
pyautogui.hotkey('ctrl','t')
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')

#site carregando
time.sleep (8)

# Navegar no sistema e encontrar o que eu quero
pyautogui.click(x=343,y=259,clicks=2)
time.sleep(3)

# Dowload da base de dados
pyautogui.click(x=485,y=253) #clicou no arquivo
time.sleep(3)
pyautogui.click(x=1168,y=155) #clicou nos 3 pontos
time.sleep(3)
pyautogui.click(x=967,y=565) #fez o dowmload
time.sleep(15)

# %%
# Calcular os indicadores (faturamento)
import pandas

tabela = pandas.read_excel(r'C:\Users\lcampos\Downloads\Vendas - Dez.xlsx')
display (tabela)

quantidade = tabela['Quantidade'].sum()
faturamento = tabela['Valor Final'].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
quantidade = tabela['Quantidade'].sum() # Soma da Quantidade

faturamento = tabela['Valor Final'].sum() # Soma do Valor Final

print(quantidade)
print(faturamento)
# Out:
# 15227
# 2917311

# %%
# Entrar no email
pyautogui.hotkey('ctrl','t')
pyperclip.copy('https://outlook.live.com/mail/0/')
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep (15)

#mandar o email
pyautogui.click(x=137,y=142) #clica para enviar novo email
time.sleep (20)
pyperclip.copy('oluca423@gmail.com') # copia o destinatario
pyautogui.hotkey('ctrl','v')
time.sleep(5)
pyautogui.press('tab')
pyperclip.copy('Modelo - Planilha') # assunto
pyautogui.hotkey('ctrl','v')
time.sleep(5)
pyautogui.press('tab')

# corpo do email

texto = f"""" Chupisco, boa tarde.

Segue link do Zabbix: https://noc.telesul.com.br/zabbix.php?action=dashboard.view

{faturamento}
{quantidade}

lalalalala

atenciosamente,

"""

pyperclip.copy(texto)
pyautogui.hotkey('ctrl','v')
time.sleep(2)
pyautogui.click(x=326,y=646)
